# %% [markdown]
# ### Установка

# %%
# !pip install setfit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setfit
#   Downloading setfit-0.7.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 4.3 MB/s eta 0:00:00
# Collecting datasets>=2.3.0
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 19.8 MB/s eta 0:00:00
# Collecting evaluate>=0.3.0
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 7.7 MB/s eta 0:00:00
# Collecting sentence-transformers>=2.2.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.3.0->setfit) (4.65.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.3.0->setfit) (2.27.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets>=2.3.0->setfit) (1.5.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.3.0->setfit) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.9 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 16.3 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.7 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.3.0->setfit) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.3.0->setfit) (6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets>=2.3.0->setfit) (23.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.3.0->setfit) (2023.4.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 37.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=2.2.1->setfit) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=2.2.1->setfit) (0.15.1+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=2.2.1->setfit) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (23.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.3/269.3 kB 19.1 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 13.3 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets>=2.3.0->setfit) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets>=2.3.0->setfit) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (1.26.15)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.25.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets>=2.3.0->setfit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets>=2.3.0->setfit) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence-transformers>=2.2.1->setfit) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=2.2.1->setfit) (8.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=2.3.0->setfit) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=248d36bd1cf0b981a0a9c34908129ff6b51b1737ae8841f92bee0fcf53022522
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, transformers, aiohttp, datasets, evaluate, sentence-transformers, setfit
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.13.4 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 sentence-transformers-2.2.2 sentencepiece-0.1.98 setfit-0.7.0 tokenizers-0.13.3 transformers-4.28.1 xxhash-3.2.0 yarl-1.9.1

# %%
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.9/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.1.98)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.15.1+cu118)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.28.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.13.4)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (2.0.0+cu118)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)

# %% [markdown]
# ### Импорты

# %%
from utils import split_df_texts_by_sentences, choose_max_rate_sentence, text_accuracy_score
from sentence_transformers.losses import CosineSimilarityLoss
from sklearn.model_selection import train_test_split
from setfit import SetFitModel, SetFitTrainer
from datasets import Dataset
import pandas as pd
import numpy as np
import joblib
import json
import pickle
import gc

# %% [markdown]
# ### Агрегация данных

# %%
with open('../data/pickle_objects/contract_enforcement.pkl', 'rb') as fp:
  contract_enforcement = pickle.load(fp)
print(len(contract_enforcement))
contract_enforcement = pd.Series(contract_enforcement)

contract_enforcement = contract_enforcement[~contract_enforcement.isna()]
contract_enforcement = contract_enforcement.values
len(contract_enforcement)
# Out:
# 988
# 984

# %%
with open('../data/pickle_objects/garantee_enforcement.pkl', 'rb') as fp:
  garantee_enforcement = pickle.load(fp)
print(len(garantee_enforcement))
garantee_enforcement = pd.Series(garantee_enforcement)

garantee_enforcement = garantee_enforcement[~garantee_enforcement.isna()]
garantee_enforcement = garantee_enforcement.values
len(garantee_enforcement)
# Out:
# 811
# 508

# %%
with open('../data/pickle_objects/nonetype.pkl', 'rb') as fp:
  nonetype_sentences = pickle.load(fp)

# %%
nonetype_sentences[:5]
# Out:
# array(['Извещение о проведении открытого конкурса в электронной форме для закупки №0328300032822000806',
#        'Общая информация', 'Номер извещения 0328300032822000806',
#        'Наименование объекта закупки', 'Поставка продуктов питания'],
#       dtype='<U1071')

# %%
len(nonetype_sentences)
# Out:
# 46897

# %%
nonetype_1500 = np.random.choice(nonetype_sentences, 1500)
df_for_contract_enforcement = pd.DataFrame(list(set(contract_enforcement)), columns=['sentence'])
df_for_nonetype = pd.DataFrame(nonetype_1500, columns=['sentence'])

# %%
df_for_contract_enforcement['label'] = 1
df_for_nonetype['label'] = 0

# %%
df_for_contract_enforcement.head()
# Out:
#                                             sentence  label
# 0  В случае если Поставщиком, при участии в закуп...      1
# 1  В размере 5% от начальной максимальной цены До...      1
# 2  Поставщик внес обеспечение исполнения Контракт...      1
# 3  Размер обеспечения исполнения договора составл...      1
# 4  Размер обеспечения исполнения договора 5 % от ...      1

# %%
df_for_nonetype.head()
# Out:
#                                             sentence  label
# 0  Восход. ие об одностороннем отказе от исполнен...      0
# 1                  Оплата Стороной неустойки (штрафа      0
# 2                1. ОБЕСПЕЧЕНИЕ ИСПОЛНЕНИЯ КОНТРАКТА      0
# 3                    Кущевская «__»__________2022 г.      0
# 4              Требования к гарантии качества товара      0

# %%
df_contract_enforcement_model = pd.concat([df_for_contract_enforcement, df_for_nonetype], axis=0)

# %%
df_contract_enforcement_model = df_contract_enforcement_model.sample(frac=1).reset_index(drop=True)

# %%
nonetype_1500 = np.random.choice(nonetype_sentences, 1500)
df_for_garantee_enforcement = pd.DataFrame(list(set(garantee_enforcement)), columns=['sentence'])
df_for_nonetype = pd.DataFrame(nonetype_1500, columns=['sentence'])

df_for_garantee_enforcement['label'] = 1
df_for_nonetype['label'] = 0

df_for_garantee_enforcement_model = pd.concat([df_for_garantee_enforcement, df_for_nonetype], axis=0)

# %%
df_for_garantee_enforcement_model = df_for_garantee_enforcement_model.sample(frac=1).reset_index(drop=True)

# %%
df_for_garantee_enforcement_model.head()
# Out:
#                                             sentence  label
# 0  Гарантии качества распространяются на все конс...      0
# 1  Коэффициент снижения (К) рассчитывается по фор...      0
# 2  Размер обеспечения гарантийных обязательств со...      1
# 3  Порядок обеспечения исполнения контракта, треб...      0
# 4  Гарантийный срок на технологическое и инженерн...      0

# %% [markdown]
# ### SetFit model

# %%
train, test = train_test_split(df_contract_enforcement_model, test_size=0.98)

# %%
len(train), len(test)
# Out:
# (31, 1567)

# %%
train_dataset = Dataset.from_pandas(train)
test_dataset = Dataset.from_pandas(test)

model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-mpnet-base-v2")

trainer = SetFitTrainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    loss_class=CosineSimilarityLoss,
    num_iterations=20,
    column_mapping={"sentence": "text", "label": "label"},
)
# Out:
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
trainer.train()
metrics = trainer.evaluate()
# Out:
# Applying column mapping to training dataset
# ***** Running training *****
#   Num examples = 1240
#   Num epochs = 1
#   Total optimization steps = 78
#   Total train batch size = 16
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/78 [00:00<?, ?it/s]
# Applying column mapping to evaluation dataset
# ***** Running evaluation *****
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %% [markdown]
# Так как модель SetFit отлично работает на малом количестве данных, можем оставить основную часть датасета в валидационной выборке

# %%
metrics
# Out:
# {'accuracy': 0.982769623484365}

# %%
del trainer

# %%
gc.collect()
# Out:
# 217

# %% [markdown]
# модель показывает accuracy 0.98 на наборе из 31 строки данных.

# %% [markdown]
# ### Batch size = 3
# попробуем уменьшить размер батча, чтобы не перегружать ОЗУ

# %%
train, test = train_test_split(df_contract_enforcement_model, test_size=0.94)

# %%
len(train), len(test)
# Out:
# (125, 1973)

# %%
del df_for_garantee_enforcement_model, df_for_nonetype, nonetype_1500, df_contract_enforcement_model, nonetype_sentences, garantee_enforcement, contract_enforcement
gc.collect()
# Out:
# 15

# %%
train_dataset = Dataset.from_pandas(train)
test_dataset = Dataset.from_pandas(test)

model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-mpnet-base-v2")

trainer = SetFitTrainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    loss_class=CosineSimilarityLoss,
    num_iterations=20,
    batch_size=3,
    column_mapping={"sentence": "text", "label": "label"},
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# Downloading (…)f39ef/.gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)0182ff39ef/README.md:   0%|          | 0.00/3.70k [00:00<?, ?B/s]
# Downloading (…)82ff39ef/config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)f39ef/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# Downloading (…)0182ff39ef/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)2ff39ef/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
trainer.train()
metrics = trainer.evaluate()
# Out:
# Applying column mapping to training dataset
# Generating Training Pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# ***** Running training *****
#   Num examples = 5000
#   Num epochs = 1
#   Total optimization steps = 1667
#   Total train batch size = 3
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/1667 [00:00<?, ?it/s]
# Applying column mapping to evaluation dataset
# ***** Running evaluation *****
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
metrics
# Out:
# {'accuracy': 0.9655347187024835}

# %%
model.predict_proba(['Размер обеспечения 1000 рублей'])
# Out:
# tensor([[0.0166, 0.9834]], dtype=torch.float64)

# %%
joblib.dump(model, '../data/pickle_objects/contract_enforcement_setfit_model.joblib')
# Out:
# ['contract_enforcement_setfit_model.joblib']

# %%
# joblib.dump(model, '/content/drive/MyDrive/забег/contract_enforcement_setfit_model.joblib')
# Out:
# ['/content/drive/MyDrive/забег/contract_enforcement_setfit_model.joblib']
# ['/content/drive/MyDrive/забег/contract_enforcement_setfit_model.joblib']

# %%
# from google.colab import files
# files.download('contract_enforcement_setfit_model.joblib')

# %% [markdown]
# ### Применение моделей на неразмеченных данных

# %% [markdown]
# так как модель получает на вход целые предложения, без особой предобработки, алгоритм выглядит так:
#
#
# 1.   Делим текст на предложения
# 2.   В зависимости от label отправляем в цикле предложения текста в соответствующуюю модель.
# 3.   Выбираем предложение с наибольшим скором

# %%
contract_enforcement_model = joblib.load('../data/models/contract_enforcement_setfit_model.joblib')
garantee_enforcement_model = joblib.load('../data/models/garantee_enforcement_setfit_model.joblib')

# %%
# contract_enforcement_model = joblib.load('/content/drive/MyDrive/забег/contract_enforcement_setfit_model.joblib')
# garantee_enforcement_model = joblib.load('/content/drive/MyDrive/забег/garantee_enforcement_setfit_model.joblib')

# %%
def get_contract_enforcement_best_sentence(text:list, max_val=0.7):
  result = {}
  for sentence in text:
    if sentence:
      res = contract_enforcement_model.predict_proba([sentence])[0][1].item()
      result[sentence] = res

  sentence, value = choose_max_rate_sentence(result)

  if value > max_val:
    return sentence, value
  return None, None

# %%
def get_garantee_enforcement_best_sentence(text:list, max_val):
  result = {}
  for sentence in text:
    if sentence:
      res = garantee_enforcement_model.predict_proba([sentence])[0][1].item()
      result[sentence] = res

  sentence, value = choose_max_rate_sentence(result)

  if value > max_val:
    return sentence, value
  return None, None

# %%
def predict(dataframe:pd.DataFrame, max_val):
  predictions = []
  # делим датафрейм на предложения 
  df_splitted_by_sentences = split_df_texts_by_sentences(dataframe.copy())
  lenght = len(df_splitted_by_sentences)

  # проходим в циклe, используем соответствующую модель
  for i in range(lenght):
    if df_splitted_by_sentences.loc[i, 'label'] == 'обеспечение исполнения контракта':
      text = df_splitted_by_sentences.loc[i, 'text']
      best_sentence, val = get_contract_enforcement_best_sentence(text)

    elif df_splitted_by_sentences.loc[i, 'label'] == 'обеспечение гарантийных обязательств':
      text = df_splitted_by_sentences.loc[i, 'text']
      best_sentence, val = get_garantee_enforcement_best_sentence(text, max_val)

    else: 
      print('Неверный формат label')
    print(f'{i} из {lenght} предсказано\n {best_sentence} score: {val}\n{best_sentence==df_splitted_by_sentences.loc[i, "target"]}\n {df_splitted_by_sentences.loc[i, "target"]}')
    predictions.append(best_sentence)

  return predictions

# %%
df = pd.read_json('../data/train_unpacked.json', encoding='utf-8')
df.sample(3)
# Out:
#              id                                               text  \
# 817   561226408  3 УТВЕРЖДЕНО приказом филиала АО «Мособлгаз» «...
# 1648  586142786  Государственное автономное учреждение Республи...
# 1641   30093679  ДОГОВОР № _________ на выполнение комплекса ра...
#
#                                      label  \
# 817       обеспечение исполнения контракта
# 1648  обеспечение гарантийных обязательств
# 1641  обеспечение гарантийных обязательств
#
#                                                  target
# 817   Сумма обеспечения исполнения договора предусмо...
# 1648  Обеспечение гарантийных обязательств установле...
# 1641                                               None

# %% [markdown]
# Для замера accuracy для уменьшения времени работы (датасет из 1799 объектов пресказывается 12 часов на колабе) возьмём 500 объектов.

# %%
df_500 = df.sample(500)
df_500.reset_index(drop=True, inplace=True)

# %%
df_500.head()
# Out:
#           id                                               text  \
# 0  214648417  УТВЕРЖДЕНА приказом Федеральной службы по экол...
# 1  445125138  Федеральное государственное бюджетное образова...
# 2  504104789  Федеральное государственное унитарное предприя...
# 3  110916274  «УТВЕРЖДАЮ» Заместитель генерального директора...
# 4   39069440  «Проект договора» Договор №_____ на поставку а...
#
#                                   label  \
# 0  обеспечение гарантийных обязательств
# 1  обеспечение гарантийных обязательств
# 2  обеспечение гарантийных обязательств
# 3      обеспечение исполнения контракта
# 4  обеспечение гарантийных обязательств
#
#                                               target
# 0                                               None
# 1                                               None
# 2                                               None
# 3  Размер обеспечения исполнения договора: 5 % от...
# 4  Обеспечение гарантийных обязательств устанавли...

# %%
pred = predict(df_500, 0.93)
# Out:
# 0 из 500 предсказано
#  УТВЕРЖДЕНА приказом Федеральной службы по экологическому, технологическому и атомному надзору от 4 марта 2019 г. score: 0.9928834958858669
# False
#  None
# 1 из 500 предсказано
#  None score: None
# True
#  None
# 2 из 500 предсказано
#  Руководитель ГЦЗ отд. 055 ________________ С.Г. score: 0.9924874849784977
# False
#  None
# 3 из 500 предсказано
#  Размер обеспечения заявок на участие в электронном аукционе: 1% от начальной (максимальной) цены договора score: 0.9870363977528901
# False
#  Размер обеспечения исполнения договора: 5 % от начальной (максимальной) цены договора
# 4 из 500 предсказано
#  Обеспечение гарантийных обязательств устанавливается в размере 1 % начальной (максимальной) цены контракта. score: 0.9935411324535374
# True
#  Обеспечение гарантийных обязательств устанавливается в размере 1 % начальной (максимальной) цены контракта.
# 5 из 500 предсказано
#  Размер обеспечения исполнения договора составляет 5 % от начальной (максимальной) цены договора – 4 450 (четыре тысячи четыреста пятьдесят) рублей 00 копеек. score: 0.9864182834800648
# False
#  Размер обеспечения исполнения договора составляет 5 % от начальной (максимальной) цены договора
# 6 из 500 предсказано
#  Размер обеспечения исполнения контракта: 5 % от цены контракта score: 0.9867063875999447
# False
#  Размер обеспечения исполнения контракта: 5 % от цены контракта, по которой заключается контракт.
# 7 из 500 предсказано
#  Застройщик в срок, указанный в пункте 8.1.3 настоящего контракта, обязан перечислить их на счет, указанный в пункте 8.1.4 настоящего контракта. score: 0.9931651227008848
# False
#  Размер обеспечения гарантийных обязательств 0,2% от начальной (максимальной) цены контракта
# 8 из 500 предсказано
#  Размер обеспечения исполнения контракта 30.00% score: 0.9865126020507543
# True
#  Размер обеспечения исполнения контракта 30.00%
# 9 из 500 предсказано
#  Размер обеспечения заявки 123435.91 Российский рубль score: 0.9863964908525374
# False
#  Размер обеспечения исполнения контракта 5.00%
# 10 из 500 предсказано
#  Поставщик до заключении Контракта предоставляет Заказчику обеспечение исполнения Контракта в соответствии с частью 6 статьи 96 Федерального закона о контрактной системе в размере 0,50 % начальной (максимальной) цены государственного контракта score: 0.9861581248928687
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 11 из 500 предсказано
#  Размер обеспечения исполнения контракта 5 % score: 0.9862211496127204
# True
#  Размер обеспечения исполнения контракта 5 %
# 12 из 500 предсказано
#  None score: None
# True
#  None
# 13 из 500 предсказано
#  Размер обеспечения исполнения Контракта составляет _______ рублей ____ копеек (30 % от начальной максимальной цены контракта). score: 0.9865941466612117
# True
#  Размер обеспечения исполнения Контракта составляет _______ рублей ____ копеек (30 % от начальной максимальной цены контракта).
# 14 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 6156.00 Российский рубль score: 0.9934924724474843
# True
#  Размер обеспечения гарантийных обязательств 6156.00 Российский рубль
# 15 из 500 предсказано
#  Размер обеспечения гарантийных обязательств составляет 10 (Десять) процентов начальной (максимальной) цены контракта - ________ руб. score: 0.9934235471017638
# True
#  Размер обеспечения гарантийных обязательств составляет 10 (Десять) процентов начальной (максимальной) цены контракта - ________ руб.
# 16 из 500 предсказано
#  Обеспечение исполнения Контракта устанавливается в размере 10 % (десять процентов) от цены контракта score: 0.9867990555802882
# True
#  Обеспечение исполнения Контракта устанавливается в размере 10 % (десять процентов) от цены контракта
# 17 из 500 предсказано
#  None score: None
# True
#  None
# 18 из 500 предсказано
#  В целях предоставления Поставщиком гарантии качества на Оборудование и возможности использования Оборудования на протяжении указанного в Контракте гарантийного срока, устанавливается обеспечение гарантийных обязательств в размере 1% начальной (максимальной) цены Контракта, что составляет 2165.85 рублей. score: 0.9935166022672385
# False
#  на протяжении указанного в Контракте гарантийного срока, устанавливается обеспечение гарантийных обязательств в размере 1% начальной (максимальной) цены Контракта, что составляет 2165.85 рублей.
# 19 из 500 предсказано
#  None score: None
# True
#  None
# 20 из 500 предсказано
#  Обеспечение исполнения договора 10% (десять процентов) от начальной (максимальной) цены договора (лота) –– 104 340,72 рублей score: 0.9865558243160768
# False
#  Обеспечение исполнения договора 10% (десять процентов) от начальной (максимальной) цены договора (лота)
# 21 из 500 предсказано
#  Обеспечение гарантийных обязательств устанавливается в размере 10 процентов от начальной (максимальной) цены договора и составляет___________________________. score: 0.9934411184444103
# True
#  Обеспечение гарантийных обязательств устанавливается в размере 10 процентов от начальной (максимальной) цены договора и составляет___________________________.
# 22 из 500 предсказано
#  Размер обеспечения исполнения контракта 2.00% score: 0.986382024784901
# True
#  Размер обеспечения исполнения контракта 2.00%
# 23 из 500 предсказано
#  Обеспечение гарантийных обязательств установлено в размере 2% начальной (максимальной) цены договора и составляет – 547 909.00 (пятьсот сорок семь тысяч девятьсот девять) рублей 00 коп. score: 0.9935722561884868
# False
#  Обеспечение гарантийных обязательств установлено в размере 2% начальной (максимальной) цены договора и составляет – 547 909.00
# 24 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 802,42, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9765203514227155
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 25 из 500 предсказано
#  Размер обеспечения исполнения Контракта составляет 5% (пять) начальной (максимальной) цены Контракта, что составляет: 26 297 (двадцать шесть тысяч двести девяносто семь) рублей 00 копейки. score: 0.9865446812686307
# False
#  Размер обеспечения исполнения Контракта составляет 5% (пять) начальной (максимальной) цены Контракта
# 26 из 500 предсказано
#  Сумма обеспечения исполнения гарантийных обязательств предусмотрена в следующем размере: 0,1 % от цены предложенной победителем закупки, НДС не облагается. score: 0.9930761504345522
# True
#  Сумма обеспечения исполнения гарантийных обязательств предусмотрена в следующем размере: 0,1 % от цены предложенной победителем закупки, НДС не облагается.
# 27 из 500 предсказано
#  Размер обеспечения исполнения контракта 5.00% score: 0.9863327435514745
# True
#  Размер обеспечения исполнения контракта 5.00%
# 28 из 500 предсказано
#  Извещения, победителем закупки должно быть представлено обеспечение исполнения договора в размере 10% от предельной цены score: 0.9869521068403425
# False
#  победителем закупки должно быть представлено обеспечение исполнения договора в размере 5% от предельной цены, указанной в п. 7.1. Извещения
# 29 из 500 предсказано
#  Размер обеспечения исполнения гарантийных обязательств составляет 2% (27 818,28 руб.) от начальной (максимальной) цены контракта и предоставляется до момента оформления документа о приемке выполненных работ по контракту (последнего этапа исполнения контракта) (при наличии этапов исполнения контракта). score: 0.9935545239816982
# False
#  Размер обеспечения исполнения гарантийных обязательств составляет 2% (27 818,28 руб.) от начальной (максимальной) цены контракта и предоставляется до момента оформления
# 30 из 500 предсказано
#  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10% от цены Контракт. score: 0.9867387031381262
# True
#  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10% от цены Контракт.
# 31 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 1 188,73, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9831431744224199
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 32 из 500 предсказано
#  Обеспечение на возврат авансового платежа не предусмотрено не предусмотрено не предусмотрено 5% (пять) от НМЦ 2 предусмотрено не предусмотрено не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза score: 0.9868138251125119
# False
#  не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза, но не менее 5% (пяти) от НМЦ
# 33 из 500 предсказано
#  None score: None
# True
#  None
# 34 из 500 предсказано
#  None score: None
# True
#  None
# 35 из 500 предсказано
#  None score: None
# True
#  None
# 36 из 500 предсказано
#  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % НМЦК. score: 0.9866282411065092
# True
#  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % НМЦК.
# 37 из 500 предсказано
#  Поставщик предоставляет Заказчику обеспечение исполнения контракта в размере 30 % от начальной (максимальной) цены контракта в сумме 95580,00 (девяносто пять тысяч пятьсот восемьдесят руб. 00 коп.). score: 0.9864696078620284
# False
#  Поставщик предоставляет Заказчику обеспечение исполнения контракта в размере 30 % от начальной (максимальной) цены контракта
# 38 из 500 предсказано
#  Сумма обеспечения договора предусмотрена в следующем размере: - 5 % от начальной (максимальной) цены договора, что составляет: 652 323,00 руб., НДС не облагается. 11.2.2 score: 0.9865661325550635
# False
#  Сумма обеспечения договора предусмотрена в следующем размере: - 5 % от начальной (максимальной) цены договора
# 39 из 500 предсказано
#  None score: None
# True
#  None
# 40 из 500 предсказано
#  Не извещение либо несвоевременное извещение другой Стороны согласно пункту 9.2 Контракта влечет за собой утрату права ссылаться на эти обстоятельства. score: 0.9935450864571598
# False
#  Размер обеспечения гарантийных обязательств составляет 1 процент начальной (максимальной) цены Контракта в размере 90890 руб.
# 41 из 500 предсказано
#  None score: None
# True
#  None
# 42 из 500 предсказано
#  None score: None
# True
#  None
# 43 из 500 предсказано
#  Обществу независимую гарантию в размере аванса на новую независимую гарантию, обеспечивающую исполнение обязательств по договору, в размере 3% от начальной (максимальной) цены договора (с НДС). 3) если обеспечение по договору было первоначально установлено договором score: 0.9869898223392628
# False
#  Если договором не предусмотрен авансовый порядок расчетов, обеспечение по договору предоставляется в размере 5% от начальной (максимальной) цены договора (с НДС)
# 44 из 500 предсказано
#  None score: None
# True
#  None
# 45 из 500 предсказано
#  Размер обеспечения гарантийных обязательств составляет _______ рублей ____ копеек (3% от начальной (максимальной) цены Контракта). score: 0.9934837168557926
# True
#  Размер обеспечения гарантийных обязательств составляет _______ рублей ____ копеек (3% от начальной (максимальной) цены Контракта).
# 46 из 500 предсказано
#  Правилами определения размера штрафа в следующем порядке: а) 1000 рублей, если цена Контракта не превышает 3 млн. рублей; б) 5000 рублей score: 0.9856455918611505
# False
#  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 10 % начальной (максимальной) цены контракта – 10 080,00 руб.
# 47 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 10142.69 Российский рубль score: 0.9934639970738786
# True
#  Размер обеспечения гарантийных обязательств 10142.69 Российский рубль
# 48 из 500 предсказано
#  Размер обеспечения исполнения Договора: 2642,13 руб. (5 % начальной (максимальной) цены Договора). score: 0.9864494640236404
# True
#  Размер обеспечения исполнения Договора: 2642,13 руб. (5 % начальной (максимальной) цены Договора).
# 49 из 500 предсказано
#  Обеспечение гарантийных обязательств предоставляется в размере 0,5% начальной (максимальной) цены Контракта на сумму________руб. ____коп. score: 0.9933788751829491
# True
#  Обеспечение гарантийных обязательств предоставляется в размере 0,5% начальной (максимальной) цены Контракта на сумму________руб. ____коп.
# 50 из 500 предсказано
#  None score: None
# True
#  None
# 51 из 500 предсказано
#  Размер обеспечения гарантийных обязательств: – предусмотрен, и составляет 10 % от НМЦК, что составляет 135 244 (сто тридцать тысяч двести сорок четыре) рубля 20 копеек. score: 0.9934592547540271
# True
#  Размер обеспечения гарантийных обязательств: – предусмотрен, и составляет 10 % от НМЦК, что составляет 135 244 (сто тридцать тысяч двести сорок четыре) рубля 20 копеек.
# 52 из 500 предсказано
#  Поставщик внес обеспечение исполнения Контракта в размере __ , что составляет 5 % score: 0.9867895033908166
# False
#  Поставщик внес обеспечение исполнения Контракта в размере __ , что составляет 5 % Цены Контракта в форме безотзывной независимой гарантии
# 53 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 531887.14 Российский рубль score: 0.9934591288318003
# True
#  Размер обеспечения гарантийных обязательств 531887.14 Российский рубль
# 54 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 13450.67 Российский рубль score: 0.9934838327410668
# True
#  Размер обеспечения гарантийных обязательств 13450.67 Российский рубль
# 55 из 500 предсказано
#  Размер обеспечения исполнения контракта 32913.05 Российский рубль score: 0.9866124660524853
# True
#  Размер обеспечения исполнения контракта 32913.05 Российский рубль
# 56 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 5 % score: 0.9866633032948177
# False
#  Обеспечение исполнения настоящего Контракта установлено в размере 5 %, что составляет 29 667,70 рублей.
# 57 из 500 предсказано
#  Размер обеспечения исполнения договора 16 859,47 (5 % от начальной (максимальной) цены договора) score: 0.9866105675441561
# True
#  Размер обеспечения исполнения договора 16 859,47 (5 % от начальной (максимальной) цены договора)
# 58 из 500 предсказано
#  Квалификация участника – деловая репутация участника закупки: наличие положительных отзывов и/или грамот от Заказчиков и/или благодарственных писем по результатам поставки товара - значимость критерия = 5% score: 0.9871679821574052
# False
#  Обеспечение договора в случае снижения участником стоимости договора на 25% и более от НМЦД
# 59 из 500 предсказано
#  Размер обеспечения гарантийных обязательств составляет 5 процентов начальной (максимальной) цены контракта, что составляет 307 676 (триста семь тысяч шестьсот семьдесят шесть) рублей 10 копеек. score: 0.9934905840785359
# False
#  Размер обеспечения гарантийных обязательств составляет 5 процентов начальной (максимальной) цены контракта, что составляет 307 676
# 60 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 946800.00 Российский рубль score: 0.9934403499731833
# True
#  Размер обеспечения гарантийных обязательств 946800.00 Российский рубль
# 61 из 500 предсказано
#  Обеспечение исполнения договора предусмотрено в размере 5% начальной (максимальной) цены договора и составляет 139 416,65 (сто тридцать девять тысяч четыреста шестнадцать) рублей score: 0.986791647808378
# False
#  Обеспечение исполнения договора предусмотрено в размере 5% начальной (максимальной) цены договора
# 62 из 500 предсказано
#  Размер обеспечения исполнения договора составляет: 30% от начальной (максимальной) цены договора score: 0.9870233462112702
# True
#  Размер обеспечения исполнения договора составляет: 30% от начальной (максимальной) цены договора
# 63 из 500 предсказано
#  Размер обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств, срок и порядок их предоставления в случае, если Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств. 5% от начальной (максимальной) цены договора, что составляет 27450 (Двадцать семь тысяч четыреста пятьдесят) рублей 00 копеек в форме независимой гарантии или внесением денежных средств на счет Заказчика. score: 0.9934988215157791
# False
#  Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств. 5% от начальной (максимальной) цены договора, что составляет 27450
# 64 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 112364.19 Российский рубль score: 0.9934613843334551
# True
#  Размер обеспечения гарантийных обязательств 112364.19 Российский рубль
# 65 из 500 предсказано
#  Размер обеспечения гарантийных обязательств составляет _______ рублей ____ копеек (1% от начальной (максимальной) цены Контракта). score: 0.9934504443968838
# True
#  Размер обеспечения гарантийных обязательств составляет _______ рублей ____ копеек (1% от начальной (максимальной) цены Контракта).
# 66 из 500 предсказано
#  Обеспечение исполнения договора составляет 5 % от начальной (максимальной) цены договора – 131 940,00 (сто тридцать одна тысяча девятьсот сорок) рублей 00 копеек. score: 0.9863692399185456
# False
#  Обеспечение исполнения договора составляет 5 % от начальной (максимальной) цены договора
# 67 из 500 предсказано
#  None score: None
# True
#  None
# 68 из 500 предсказано
#  Размер обеспечения исполнения Контракта составляет 5% (пять процентов) от цены Контракта score: 0.9865071014857566
# False
#  Размер обеспечения исполнения Контракта составляет 5% (пять процентов) от цены Контракта, что составляет ___________ ( ) рублей
# 69 из 500 предсказано
#  Обеспечение исполнения договора 0% score: 0.9858692747914817
# True
#  Обеспечение исполнения договора 0%
# 70 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 5%. score: 0.986200644127086
# True
#  Обеспечение исполнения настоящего Контракта установлено в размере 5%.
# 71 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 10 % от начальной (максимальной) цены контракта, что составляет: 160 500,00 руб. (сто шестьдесят тысяч пятьсот рублей) 00 копеек. score: 0.9934657008291725
# False
#  Размер обеспечения гарантийных обязательств 10 % от начальной (максимальной) цены контракта, что составляет: 160 500,00 руб.
# 72 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 31600.51 Российский рубль score: 0.9935023940251893
# True
#  Размер обеспечения гарантийных обязательств 31600.51 Российский рубль
# 73 из 500 предсказано
#  Размер обеспечения исполнения договора составляет 5% от итоговой цены договора. score: 0.9862748609429796
# True
#  Размер обеспечения исполнения договора составляет 5% от итоговой цены договора.
# 74 из 500 предсказано
#  Размер обеспечения гарантийных обязательств – 5 % начальной (максимальной) цены контракта, что составляет 172149,85 рублей (сто семьдесят две тысячи сто сорок девять рубля 85 копеек). 10.2 score: 0.9935076376331357
# False
#  Размер обеспечения гарантийных обязательств – 5 % начальной (максимальной) цены контракта, что составляет 172149,85 рублей
# 75 из 500 предсказано
#  Размер обеспечения исполнения контракта 10.00% score: 0.9863875463063003
# True
#  Размер обеспечения исполнения контракта 10.00%
# 76 из 500 предсказано
#  8.2.2. score: 0.36526123433390206
# False
#  Заказчик вправе установить в документации о закупке требование к обеспечению исполнения договора в размере не более 5 (пяти) процентов от начальной (максимальной) цены договора с НДС
# 77 из 500 предсказано
#  None score: None
# True
#  None
# 78 из 500 предсказано
#  None score: None
# True
#  None
# 79 из 500 предсказано
#  Размер обеспечения исполнения контракта 480281.51 Российский рубль score: 0.9864031382936873
# True
#  Размер обеспечения исполнения контракта 480281.51 Российский рубль
# 80 из 500 предсказано
#  Размер обеспечения исполнения договора устанавливается в размере 5% начальной цены договора. score: 0.9865356981657543
# True
#  Размер обеспечения исполнения договора устанавливается в размере 5% начальной цены договора.
# 81 из 500 предсказано
#  Размер обеспечения исполнения договора составляет 5% от начальной (максимальной) цены договора score: 0.9865855491176038
# True
#  Размер обеспечения исполнения договора составляет 5% от начальной (максимальной) цены договора
# 82 из 500 предсказано
#  Размер обеспечения гарантийных обязательств не может превышать 20% от начальной (максимальной) цены договора. score: 0.9933655775467382
# True
#  Размер обеспечения гарантийных обязательств не может превышать 20% от начальной (максимальной) цены договора.
# 83 из 500 предсказано
#  Размер обеспечения исполнения контракта 5.00% score: 0.9863327435514745
# True
#  Размер обеспечения исполнения контракта 5.00%
# 84 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 1 955,69, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9851416922330013
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 85 из 500 предсказано
#  Обеспечение гарантийных обязательств по Контракту предусмотрено в размере 1% от начальной (максимальной) цены Контракта, что составляет 410 (четыреста десять) рублей 22 копейки. score: 0.9935629020947736
# False
#  Обеспечение гарантийных обязательств по Контракту предусмотрено в размере 1% от начальной (максимальной) цены Контракта, что составляет 410 (четыреста десять) рублей 22 копейки
# 86 из 500 предсказано
#  Требование предоставления обеспечения гарантийных обязательств - установлено в размере 10% от НМЦК, что составляет 273 640,08 руб. (двести семьдесят три тысячи шестьсот сорок рублей 08 копеек) score: 0.9934889946227093
# False
#  Требование предоставления обеспечения гарантийных обязательств - установлено в размере 10% от НМЦК, что составляет 273 640,08 руб.
# 87 из 500 предсказано
#  Например, если в договоре указано обеспечение исполнение договора в размере 5% от цены договора score: 0.9869682659506085
# False
#  обеспечение исполнения договора в размере 5 % от цены договора
# 88 из 500 предсказано
#  None score: None
# True
#  None
# 89 из 500 предсказано
#  Размер обеспечения исполнения гарантийных обязательства по Контракту –3512 (Три тысячи пятьсот двенадцать) рублей 00 копеек (2 % от начальной максимальной цены контракта). score: 0.9936051357751933
# True
#  Размер обеспечения исполнения гарантийных обязательства по Контракту –3512 (Три тысячи пятьсот двенадцать) рублей 00 копеек (2 % от начальной максимальной цены контракта).
# 90 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 116841.19 Российский рубль score: 0.9934827083605795
# True
#  Размер обеспечения гарантийных обязательств 116841.19 Российский рубль
# 91 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 7500.00 Российский рубль score: 0.9934079905634142
# True
#  Размер обеспечения гарантийных обязательств 7500.00 Российский рубль
# 92 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 5% от НМЦК. score: 0.9933273439160486
# True
#  Размер обеспечения гарантийных обязательств 5% от НМЦК.
# 93 из 500 предсказано
#  None score: None
# True
#  None
# 94 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере __________ рублей _______ копеек (5 процентов цены Контракта). score: 0.986642141119816
# True
#  Обеспечение исполнения настоящего Контракта установлено в размере __________ рублей _______ копеек (5 процентов цены Контракта).
# 95 из 500 предсказано
#  Обеспечение исполнения Контракта установлено в размере 10 (десять) % от цены score: 0.9865685818725665
# False
#  Обеспечение исполнения Контракта установлено в размере 10 (десять) % от цены, по которой заключается Контракт, что составляет __
# 96 из 500 предсказано
#  Размер обеспечения исполнения контракта (договора) составляет: 0,50% от цены score: 0.986661897212317
# True
#  Размер обеспечения исполнения контракта (договора) составляет: 0,50% от цены
# 97 из 500 предсказано
#  Размер обеспечения исполнения контракта 9724.00 Российский рубль score: 0.9866446013331363
# True
#  Размер обеспечения исполнения контракта 9724.00 Российский рубль
# 98 из 500 предсказано
#  None score: None
# True
#  None
# 99 из 500 предсказано
#  Обеспечение гарантийных обязательств устанавливается в размере 10 % (Десять процентов) от начальной (максимальной) цены контракта, что составляет 36 099,87 (Тридцать шесть тысяч девяносто девять руб. 87 коп.) рублей. score: 0.9935547936266254
# False
#  Обеспечение гарантийных обязательств устанавливается в размере 10 % (Десять процентов) от начальной (максимальной) цены контракта, что составляет 36 099,87
# 100 из 500 предсказано
#  Размер обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств, срок и порядок их предоставления в случае, если Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств 5%, 132 589,74 (Сто тридцать две тысячи пятьсот восемьдесят девять рублей 74 копеек) рублей. score: 0.9934873854760473
# False
#  Заказчиком установлено требование обеспечения исполнения договора и (или) обеспечения исполнения гарантийных обязательств 5%, 132 589,74 (Сто тридцать две тысячи пятьсот восемьдесят девять рублей 74 копеек) рублей.
# 101 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 149,58, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9683335248359308
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 102 из 500 предсказано
#  Размер обеспечения гарантийных обязательств составляет: 0,00% от начальной (максимальной) цены контракта, что составляет 0,00 рублей. score: 0.9935384924222773
# False
#  Заказчик № 1: Размер обеспечения гарантийных обязательств составляет: 0,00% от начальной (максимальной) цены контракта, что составляет 0,00 рублей. Заказчик № 2: Размер обеспечения гарантийных обязательств составляет: 0,00%
# 103 из 500 предсказано
#  Обеспечение исполнения обязательств по договору: требуется, в размере не менее 5 % от цены договора. score: 0.986716864204593
# True
#  Обеспечение исполнения обязательств по договору: требуется, в размере не менее 5 % от цены договора.
# 104 из 500 предсказано
#  Сумма обеспечения исполнения гарантийных обязательств предусмотрена в следующем размере: 4 % от цены предложенной победителем закупки, НДС не облагается. score: 0.9934298579400452
# True
#  Сумма обеспечения исполнения гарантийных обязательств предусмотрена в следующем размере: 4 % от цены предложенной победителем закупки, НДС не облагается.
# 105 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 2 % (___________ рублей) начальной (максимальной) цены контракта. 8 consultantplus://offline/ref=0F7FC5B4548E7428D0E883A2DA623D1EED6515026DC6423AD26748F36C5670D0597D2411B1DF465161A1K file:///%D0%AE%D1%80%D0%B8%D1%81%D1%82%D1%8B/%D0%9A%D0%B0%D1%80%D0%B5%D0%B2%20%D0%92.%D0%92/%D0%9F%D0%A0%D0%9E%D0%95%D0%9A%D0%A2%20%D0%93%D0%9A%20%20%D1%81%D0%B2%D1%8B%D1%88%D0%B5%20100%20%D0%BC%D0%BB%D0%BD%20%D0%BE%D0%B1%D0%BE%D1%80%D1%83%D0%B4%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%9A%D0%A1%20%D0%A4%D0%90%D0%9F.doc#P156 file:///%D0%AE%D1%80%D0%B8%D1%81%D1%82%D1%8B/%D0%9A%D0%B0%D1%80%D0%B5%D0%B2%20%D0%92.%D0%92/%D0%9F%D0%A0%D0%9E%D0%95%D0%9A%D0%A2%20%D0%93%D0%9A%20%20%D1%81%D0%B2%D1%8B%D1%88%D0%B5%20100%20%D0%BC%D0%BB%D0%BD%20%D0%BE%D0%B1%D0%BE%D1%80%D1%83%D0%B4%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%9A%D0%A1%20%D0%A4%D0%90%D0%9F.doc#P552 file:///%D0%AE%D1%80%D0%B8%D1%81%D1%82%D1%8B/%D0%9A%D0%B0%D1%80%D0%B5%D0%B2%20%D0%92.%D0%92/%D0%9F%D0%A0%D0%9E%D0%95%D0%9A%D0%A2%20%D0%93%D0%9A%20%20%D1%81%D0%B2%D1%8B%D1%88%D0%B5%20100%20%D0%BC%D0%BB%D0%BD%20%D0%BE%D0%B1%D0%BE% score: 0.9912850365168561
# False
#  Размер обеспечения гарантийных обязательств 2 % (___________ рублей) начальной (максимальной) цены контракта.
# 106 из 500 предсказано
#  Размер обеспечения гарантийных обязательств: 10 % от начальной (максимальной) цены договора, что составляет 166 680 (Сто шестьдесят шесть тысяч восемьсот) рублей 00 копеек. score: 0.9935253457549714
# False
#  Установлен Размер обеспечения гарантийных обязательств: 10 % от начальной (максимальной) цены договора, что составляет 166 680
# 107 из 500 предсказано
#  Размер обеспечения исполнения контракта 5.00% score: 0.9863327435514745
# True
#  Размер обеспечения исполнения контракта 5.00%
# 108 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 2,00 % от начальной (максимальной) цены договора в размере 10 400 рублей 00 копеек. 14.21 score: 0.9935032341571886
# False
#  Размер обеспечения гарантийных обязательств 2,00 % от начальной (максимальной) цены договора в размере 10 400 рублей 00 копеек.
# 109 из 500 предсказано
#  Начальная (максимальная) цена договора: 650 000,00 рублей score: 0.9910536552868685
# False
#  None
# 110 из 500 предсказано
#  В случае н 5661(67932) score: 0.004027626761091747
# False
#  Обеспечение исполнения настоящего Контракта устанавливается в размере 1 процент от начальной (максимальной) цены Контракта и составляет ___
# 111 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 153,30, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9631600338088736
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 112 из 500 предсказано
#  Сумма обеспечения исполнения договора составляет 10 % цены Договора score: 0.9867745036153274
# False
#  Сумма обеспечения исполнения договора составляет 10 % цены Договора, что составляет __________ (_________________
# 113 из 500 предсказано
#  Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств в размере 5.00 % от начальной (максимальной) цены контракта, что составляет 327895.74 руб. score: 0.9935643895426349
# True
#  Подрядчик обязан предоставить Заказчику обеспечение гарантийных обязательств в размере 5.00 % от начальной (максимальной) цены контракта, что составляет 327895.74 руб.
# 114 из 500 предсказано
#  Обеспечение на возврат авансового платежа не предусмотрено не предусмотрено не предусмотрено 5% (пять) от НМЦ 2 предусмотрено не предусмотрено не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза score: 0.9868138251125119
# False
#  не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза, но не менее 5% (пяти) от НМЦ
# 115 из 500 предсказано
#  Государственному заказчику обеспечение гарантийных обязательств в размере 5% начальной максимальной цены Контракта, что составляет ________________ (___________________) рублей. score: 0.9934594057709831
# False
#  предоставляет Государственному заказчику обеспечение гарантийных обязательств в размере 5% начальной максимальной цены Контракта, что составляет ________________ (___________________) рублей
# 116 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 1209045.29 Российский рубль score: 0.9935054346137212
# True
#  Размер обеспечения гарантийных обязательств 1209045.29 Российский рубль
# 117 из 500 предсказано
#  Размер обеспечения исполнения контракта 10.00% score: 0.9863875463063003
# True
#  Размер обеспечения исполнения контракта 10.00%
# 118 из 500 предсказано
#  Размер обеспечения исполнения контракта составляет 10% от цены контракта. score: 0.9864208557900327
# True
#  Размер обеспечения исполнения контракта составляет 10% от цены контракта.
# 119 из 500 предсказано
#  Устанавливается в размере 5% от цены договора и составляет ______________ руб score: 0.5263699365369895
# False
#  Размер обеспечения исполнения договора Устанавливается в размере 5% от цены договора и составляет ______________
# 120 из 500 предсказано
#  Обеспечение исполнения договора предусмотрено в размере 5% максимального значения цены договора и составляет 1 038 750,00 (Один миллион тридцать восемь тысяч семьсот пятьдесят рублей ноль копеек) score: 0.9864707350379103
# False
#  Обеспечение исполнения договора предусмотрено в размере 5% максимального значения цены договора
# 121 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 10584.09 Российский рубль score: 0.9934789461167624
# True
#  Размер обеспечения гарантийных обязательств 10584.09 Российский рубль
# 122 из 500 предсказано
#  Исполнение гарантийного обязательства по договору составляет 5 % от начальной (максимальной) цены Договора. score: 0.9934410543004213
# False
#  Размер обеспечения Исполнение гарантийного обязательства по договору составляет 5 % от начальной (максимальной) цены Договора.
# 123 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 10% от начальной (максимальной) цены контракта (цены лота) –73 842,00 (Семьдесят три тысячи восемьсот сорок два рубля 00 коп.) (ч. 6 ст. 96 Закона № 44-ФЗ). score: 0.9864418867911872
# False
#  Обеспечение исполнения настоящего Контракта установлено в размере 10% от начальной (максимальной) цены контракта (цены лота)
# 124 из 500 предсказано
#  None score: None
# True
#  None
# 125 из 500 предсказано
#  Требование о предоставлении участником обеспечения исполнения договора, при этом договор заключается только после предоставления участником такого обеспечения исполнения договора в размере 30% (тридцати процентов) от начальной (максимальной) цены договора без учета НДС, что составляет 25 809,00 (двадцать пять тысяч восемьсот девять) рублей 00 копеек. 1.5 score: 0.9867593857039565
# False
#  к такому участнику применяется требование об обеспечении исполнения договора в размере 30% (тридцати процентов) от начальной (максимальной) цены договора без учета НДС
# 126 из 500 предсказано
#  Государственному заказчику обеспечение гарантийных обязательств в размере 5% начальной максимальной цены Контракта, что составляет ________________ (___________________) рублей. score: 0.9934594057709831
# False
#  предоставляет Государственному заказчику обеспечение гарантийных обязательств в размере 5% начальной максимальной цены Контракта, что составляет ________________ (___________________) рублей
# 127 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 99998.14 Российский рубль score: 0.9934851898399264
# True
#  Размер обеспечения гарантийных обязательств 99998.14 Российский рубль
# 128 из 500 предсказано
#  Размер обеспечения исполнения контракта 20.00% score: 0.9863434118360587
# True
#  Размер обеспечения исполнения контракта 20.00%
# 129 из 500 предсказано
#  Юридический/почтовый адрес: 397560, score: 0.9839269668315943
# False
#  обеспечения исполнения договора в размере, превышающем в полтора раза размер обеспечения исполнения договора, указанный в документации о закупке, но не менее, чем 10 (десять) процентов от начальной (максимальной) цены договора
# 130 из 500 предсказано
#  Размер обеспечения исполнения контракта 0.50% score: 0.9860711920603594
# True
#  Размер обеспечения исполнения контракта 0.50%
# 131 из 500 предсказано
#  Размер обеспечения исполнения контракта устанавливается в размере 10 % от цены по которой заключается контракт. score: 0.9862947284442102
# True
#  Размер обеспечения исполнения контракта устанавливается в размере 10 % от цены по которой заключается контракт.
# 132 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 36990.74 Российский рубль score: 0.9935007281936493
# True
#  Размер обеспечения гарантийных обязательств 36990.74 Российский рубль
# 133 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 11257.14 Российский рубль score: 0.9935117229289911
# True
#  Размер обеспечения гарантийных обязательств 11257.14 Российский рубль
# 134 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 5%. score: 0.986200644127086
# True
#  Обеспечение исполнения настоящего Контракта установлено в размере 5%.
# 135 из 500 предсказано
#  Размер обеспечения исполнения контракта 5.00% score: 0.9863327435514745
# True
#  Размер обеспечения исполнения контракта 5.00%
# 136 из 500 предсказано
#  Размер обеспечения исполнения Контракта устанавливается в размере 10 % от цены score: 0.9868645555440457
# False
#  Размер обеспечения исполнения Контракта устанавливается в размере 10 % от цены, по которой заключается Контракт и составляет______
# 137 из 500 предсказано
#  Оказание услуг по техническому обслуживанию генетического секвенатора ИКЗ 222027591301202750100100710013312244 г. score: 0.9563307582584313
# False
#  None
# 138 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 55550.00 Российский рубль score: 0.9934748493322939
# True
#  Размер обеспечения гарантийных обязательств 55550.00 Российский рубль
# 139 из 500 предсказано
#  Обеспечение исполнения обязательств по договору: - обеспечение исполнения договора в размере не менее 5.00 % от цены договора score: 0.9867741820397646
# False
#  обеспечение исполнения договора в размере не менее 5.00 % от цены договора
# 140 из 500 предсказано
#  Если договором предусмотрено предоставление обеспечения гарантийных обязательств, размер такого обеспечения может составлять от 0,01% до 10% от цены договора (лота) (максимального значения цены договора). score: 0.9922408253288523
# True
#  Если договором предусмотрено предоставление обеспечения гарантийных обязательств, размер такого обеспечения может составлять от 0,01% до 10% от цены договора (лота) (максимального значения цены договора).
# 141 из 500 предсказано
#  None score: None
# True
#  None
# 142 из 500 предсказано
#  Если в извещении о закупке и (или) документации о закупке установлено требование к обеспечению исполнения договора, размер такого обеспечения: 1) не может превышать 5 процентов начальной (максимальной) цены договора (цены лота) score: 0.9867351428584565
# True
#  Если в извещении о закупке и (или) документации о закупке установлено требование к обеспечению исполнения договора, размер такого обеспечения: 1) не может превышать 5 процентов начальной (максимальной) цены договора (цены лота)
# 143 из 500 предсказано
#  Устанавливается на весь срок действия договора в размере 5 (пять)% от цены договора: score: 0.9865217279154601
# False
#  Размер обеспечения исполнения договора Устанавливается на весь срок действия договора в размере 5 (пять)% от цены договора
# 144 из 500 предсказано
#  Сибирь ________________ /Тэрри А.В./ «____» _______________ 2022г. ента заключения договора, Заказчик в течение 5 (пяти) рабочих дней со дня окончания указанного срока обязан принять решение об одностороннем отказе от исполнения договора. score: 0.9927737217654112
# False
#  взамен ранее предоставленного обеспечения гарантийных обязательств новое обеспечение гарантийных обязательств.
# 145 из 500 предсказано
#  Размер обеспечения гарантийных обязательств составляет: 0,00 % от начальной (максимальной) цены контракта, что составляет 0,00 рублей. score: 0.9935384924222773
# True
#  Размер обеспечения гарантийных обязательств составляет: 0,00 % от начальной (максимальной) цены контракта, что составляет 0,00 рублей.
# 146 из 500 предсказано
#  Обеспечение исполнения Контракта предоставляется в размере 10 % от цены Контракта в сумме________ (сумма указывается прописью) рублей. score: 0.9835231265983654
# False
#  Обеспечение исполнения Контракта предоставляется в размере 10 % от цены Контракта в сумме________
# 147 из 500 предсказано
#  Размер обеспечения исполнения контракта 5.00% score: 0.9863327435514745
# True
#  Размер обеспечения исполнения контракта 5.00%
# 148 из 500 предсказано
#  Извещении о проведении закупки установлено требование о предоставлении обеспечения исполнения договора, то только после предоставления таким участником одного из следующего: а) обеспечения исполнения договора в размере, превышающем в полтора раза размер обеспечения исполнения договора, указанный в извещении о закупке, но не менее, чем 10% от начальной (максимальной) цены договора; б) обеспечения исполнения договора в размере score: 0.03744909893641933
# False
#  обеспечения исполнения договора в размере, превышающем в полтора раза размер обеспечения исполнения договора, указанный в извещении о закупке, но не менее, чем 10% от начальной (максимальной) цены договора
# 149 из 500 предсказано
#  Размер обеспечения исполнения контракта 113630.08 Российский рубль score: 0.9864197479190194
# True
#  Размер обеспечения исполнения контракта 113630.08 Российский рубль
# 150 из 500 предсказано
#  Размер обеспечения исполнения договора: 5 % от начальной (максимальной) цены договора score: 0.9867287529885798
# True
#  Размер обеспечения исполнения договора: 5 % от начальной (максимальной) цены договора
# 151 из 500 предсказано
#  Размер обеспечения гарантийных обязательств подрядчика устанавливается в размере 5% от начальной (максимальной) цены договора и составляет ___________. score: 0.9934950349417879
# True
#  Размер обеспечения гарантийных обязательств подрядчика устанавливается в размере 5% от начальной (максимальной) цены договора и составляет ___________.
# 152 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 10,00 % от начальной (максимальной) цены Контракта. score: 0.98576769908986
# True
#  Обеспечение исполнения настоящего Контракта установлено в размере 10,00 % от начальной (максимальной) цены Контракта.
# 153 из 500 предсказано
#  Размер обеспечения исполнения контракта составляет 5% от начальной (максимальной) цены контракта score: 0.9866103634285558
# True
#  Размер обеспечения исполнения контракта составляет 5% от начальной (максимальной) цены контракта
# 154 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 18587.74 Российский рубль score: 0.9934943553916122
# True
#  Размер обеспечения гарантийных обязательств 18587.74 Российский рубль
# 155 из 500 предсказано
#  Чебоксары 2022 год СОДЕРЖАНИЕ СОДЕРЖАНИЕ 2 I. ОБЩИЕ УСЛОВИЯ ПРОВЕДЕНИЯ закупки score: 0.9493424301151213
# False
#  None
# 156 из 500 предсказано
#  Размер обеспечения исполнения договора: 5% от начальной (максимальной) цены договора 18 971,89 руб., НДС не облагается. score: 0.9864288048290794
# False
#  Размер обеспечения исполнения договора: 5% от начальной (максимальной) цены договора 18 971,89 руб.
# 157 из 500 предсказано
#  None score: None
# True
#  None
# 158 из 500 предсказано
#  Размер обеспечения исполнения договора: 5 % начальной максимальной цены договора (цены лота) и составляет 463 627 рублей 14 копеек (Четыреста шестьдесят три тысячи шестьсот двадцать семь рублей 14 копеек). score: 0.9866511352290324
# False
#  Размер обеспечения исполнения договора: 5 % начальной максимальной цены договора (цены лота)
# 159 из 500 предсказано
#  Обеспечение исполнения контракта: - размер обеспечения исполнения контракта - 5 (пяти) процентов цены контракта. score: 0.9865014054333844
# False
#  размер обеспечения исполнения контракта - 5 (пяти) процентов цены контракта.
# 160 из 500 предсказано
#  Балаковской АЭС с установкой линейной ячейки 220 кВ, строительство ПС 220 кВ РЦОД с установкой двух трансформаторов 220/10 кВ мощностью 100 МВА каждый score: 0.9736132493834602
# False
#  None
# 161 из 500 предсказано
#  Обеспечение исполнения настоящего договора предоставляется поставщиком в размере: 3% начальной (максимальной) цены договора на сумму: 50 589,44 рублей. score: 0.9869247534387444
# False
#  Обеспечение исполнения настоящего договора предоставляется поставщиком в размере: 3% начальной (максимальной) цены договора
# 162 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 6050.56 Российский рубль score: 0.9935116341135598
# True
#  Размер обеспечения гарантийных обязательств 6050.56 Российский рубль
# 163 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 1 058,71, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9838766806007505
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 164 из 500 предсказано
#  Размер обеспечения гарантийных 2 % от начальной (максимальной) цены обязательств контракта – 7 455 (семь тысяч четыреста пятьдесят пять) рублей 00 копеек. score: 0.99361142869389
# False
#  Размер обеспечения гарантийных 2 % от начальной (максимальной) цены обязательств контракта – 7 455
# 165 из 500 предсказано
#  Размер обеспечения гарантийных обязательств по Контракту составляет 1% от начальной (максимальной) цены Контракта в сумме 348550,62 (триста сорок восемь тысяч пятьсот пятьдесят) рублей 62 копеек. 11.5 score: 0.9935422802525703
# False
#  Размер обеспечения гарантийных обязательств по Контракту составляет 1% от начальной (максимальной) цены Контракта в сумме 348550,62
# 166 из 500 предсказано
#  Размер обеспечения исполнения контракта 239308.80 Российский рубль score: 0.986456997562911
# True
#  Размер обеспечения исполнения контракта 239308.80 Российский рубль
# 167 из 500 предсказано
#  None score: None
# True
#  None
# 168 из 500 предсказано
#  None score: None
# True
#  None
# 169 из 500 предсказано
#  Участник закупки, с которым заключается договор, до заключения договора предоставляет обеспечение исполнения договора в размере 5 % от начальной (максимальной) цены договора: 826 977,71 руб. score: 0.9864775090085606
# True
#  Участник закупки, с которым заключается договор, до заключения договора предоставляет обеспечение исполнения договора в размере 5 % от начальной (максимальной) цены договора: 826 977,71 руб.
# 170 из 500 предсказано
#  Размер обеспечения гарантийных обязательств: 5% от начальной (максимальной) цены контракта (максимального значения цены контракта), что составляет 567 821,67 (пятьсот шестьдесят семь тысяч восемьсот двадцать один) рубль 67 копеек score: 0.9934925375850576
# False
#  Размер обеспечения гарантийных обязательств: 5% от начальной (максимальной) цены контракта (максимального значения цены контракта)
# 171 из 500 предсказано
#  13. ОБЕСПЕЧЕНИЕ ГАРАНТИЙНЫХ ОБЯЗАТЕЛЬСТВ 13.1.Размер обеспечения гарантийных обязательств составляет 10 процентов начальной (максимальной) цены Контракта. score: 0.9934291569065214
# False
#  Размер обеспечения гарантийных обязательств составляет 10 процентов начальной (максимальной) цены Контракта.
# 172 из 500 предсказано
#  Размер обеспечения исполнения контракта 10.00% score: 0.9863875463063003
# True
#  Размер обеспечения исполнения контракта 10.00%
# 173 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 49990.00 Российский рубль score: 0.9934624911616223
# True
#  Размер обеспечения гарантийных обязательств 49990.00 Российский рубль
# 174 из 500 предсказано
#  Размер обеспечения исполнения контракта 5.00% score: 0.9863327435514745
# True
#  Размер обеспечения исполнения контракта 5.00%
# 175 из 500 предсказано
#  В размере 5% от начальной максимальной цены Договора в сумме 15801,15 руб. score: 0.985996635923381
# False
#  В размере 5% от начальной максимальной цены Договора в сумме 15801,15
# 176 из 500 предсказано
#  Устанавливается обеспечение договора в размере 5% от начальной (максимальной) цены договора score: 0.9866600509908924
# True
#  Устанавливается обеспечение договора в размере 5% от начальной (максимальной) цены договора
# 177 из 500 предсказано
#  None score: None
# True
#  None
# 178 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 549,95, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9779518415650025
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 179 из 500 предсказано
#  Размер обеспечения гарантийных обязательств установлен в размере 1 % начальной (максимальной) цены контракта, что составляет 21 355,84 (Двадцать одна тысяча триста пятьдесят пять рублей 84 копейки) рублей. score: 0.9935722122993187
# False
#  Размер обеспечения гарантийных обязательств установлен в размере 1 % начальной (максимальной) цены контракта, что составляет 21 355,84
# 180 из 500 предсказано
#  None score: None
# True
#  None
# 181 из 500 предсказано
#  Размер обеспечения гарантийных обязательств составляет: 0,00 % от начальной (максимальной) цены контракта, что составляет 0,00 рублей. score: 0.9935384924222773
# True
#  Размер обеспечения гарантийных обязательств составляет: 0,00 % от начальной (максимальной) цены контракта, что составляет 0,00 рублей.
# 182 из 500 предсказано
#  None score: None
# True
#  None
# 183 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 48921.67 Российский рубль score: 0.9934957663761989
# True
#  Размер обеспечения гарантийных обязательств 48921.67 Российский рубль
# 184 из 500 предсказано
#  9. ОБЕСПЕЧЕНИЕ ИСПОЛНЕНИЯ ДОГОВОРА score: 0.03975866665510309
# False
# ...
# 439 из 500 предсказано
#  6.9.1. score: 0.24028412320026077
# False
#  В случае если закупка проводится только для субъектов малого и среднего предпринимательства размер обеспечения исполнения договора: а) не может превышать 5 (пяти) процентов начальной (максимальной) цены договора
# 440 из 500 предсказано
#  Размер обеспечения гарантийных обязательств устанавливается в размере 1 % от начальной (максимальной) цены контракта, что составляет ___________ рублей. score: 0.9935483070759435
# True
#  Размер обеспечения гарантийных обязательств устанавливается в размере 1 % от начальной (максимальной) цены контракта, что составляет ___________ рублей.
# 441 из 500 предсказано
#  Место нахождения Заказчика: 644027, г. score: 0.9364285831792601
# False
#  None
# 442 из 500 предсказано
#  Размер обеспечения гарантийных обязательств составляет 417 002,52 (Четыреста семнадцать тысяч два) рублей 52 копеек (10 процентов начальной (максимальной) цены Контракта). score: 0.993493313034487
# True
#  Размер обеспечения гарантийных обязательств составляет 417 002,52 (Четыреста семнадцать тысяч два) рублей 52 копеек (10 процентов начальной (максимальной) цены Контракта).
# 443 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 5%. score: 0.986200644127086
# True
#  Обеспечение исполнения настоящего Контракта установлено в размере 5%.
# 444 из 500 предсказано
#  None score: None
# True
#  None
# 445 из 500 предсказано
#  Размер обеспечения заявки 517.60 Российский рубль score: 0.9864253929879825
# False
#  Размер обеспечения исполнения контракта 3105.60 Российский рубль
# 446 из 500 предсказано
#  None score: None
# False
#  Размер обеспечения гарантийных обязательств по договору 1 (один) процент от общей цены договора.
# 447 из 500 предсказано
#  Подрядчик обязан предоставить обеспечение исполнения гарантийных обязательств в размере 0,75% от начальной (максимальной) цены контракта, что составляет – 712 019,85 рублей. score: 0.9934852642099012
# True
#  Подрядчик обязан предоставить обеспечение исполнения гарантийных обязательств в размере 0,75% от начальной (максимальной) цены контракта, что составляет – 712 019,85 рублей.
# 448 из 500 предсказано
#  None score: None
# True
#  None
# 449 из 500 предсказано
#  None score: None
# True
#  None
# 450 из 500 предсказано
#  Обеспечение исполнения гарантийных обязательств по настоящему Договору представляется на сумму не менее 5% от стоимости всех выполненных работ. score: 0.9934501344499691
# True
#  Обеспечение исполнения гарантийных обязательств по настоящему Договору представляется на сумму не менее 5% от стоимости всех выполненных работ.
# 451 из 500 предсказано
#  Размер обеспечения исполнения контракта 100.00% score: 0.9857861659315323
# True
#  Размер обеспечения исполнения контракта 100.00%
# 452 из 500 предсказано
#  Поставщик при заключении Договора должен предоставить Заказчику обеспечение исполнения Договора в размере 5 % начальной (максимальной) цены Договора в сумме 48322 (сорок восемь тысяч триста двадцать два рубля) 25 копеек. score: 0.9865911083660795
# False
#  Поставщик при заключении Договора должен предоставить Заказчику обеспечение исполнения Договора в размере 5 % начальной (максимальной) цены Договора
# 453 из 500 предсказано
#  Обеспечение исполнения настоящего договора предоставляется Поставщиком в размере: 5 % от начальной (максимальной) цены договора в сумме 7501,66 рублей. score: 0.9867334160927311
# False
#  Обеспечение исполнения настоящего договора предоставляется Поставщиком в размере: 5 % от начальной (максимальной) цены договора в сумме 7501,66
# 454 из 500 предсказано
#  Обеспечение исполнения договора 5 % начальной (максимальной) цены договора, что составляет 6 183 (шесть тысяч сто восемьдесят три) рубля 30 копеек score: 0.9866270253222208
# False
#  Обеспечение исполнения договора 5 % начальной (максимальной) цены договора
# 455 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 334.97 Российский рубль score: 0.9934513050402112
# True
#  Размер обеспечения гарантийных обязательств 334.97 Российский рубль
# 456 из 500 предсказано
#  Обеспечение на возврат авансового платежа 1 не предусмотрено не предусмотрено не предусмотрено 3% (три) от начальной (максимальной) цены договора 2 предусмотрено не предусмотрено не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза score: 0.9869675550803612
# False
#  не предусмотрено увеличенное от первоначально установленного обеспечения исполнения договора в 1,5 (полтора) раза, но не более 5% (пяти) от начальной (максимальной) цены договора
# 457 из 500 предсказано
#  Размер обеспечения исполнения контракта 10% от цены контракта score: 0.9866994406480124
# True
#  Размер обеспечения исполнения контракта 10% от цены контракта
# 458 из 500 предсказано
#  Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота). score: 0.9935062758284213
# True
#  Размер обеспечения исполнения гарантийных обязательств не может превышать 2 % начальной (максимальной) цены договора (цены лота).
# 459 из 500 предсказано
#  Обеспечение исполнения обязательств по договору: требуется; · обеспечение исполнения договора в размере не менее 5% от цены договора; · обеспечение исполнения гарантийных обязательств в размере не менее 0,5 % от цены договора. score: 0.9933929549750156
# False
#  обеспечение исполнения гарантийных обязательств в размере не менее 0,5 %
# 460 из 500 предсказано
#  Размер обеспечения гарантийных обязательств: 1% от начальной (максимальной) цены контракта (договора), что составляет 15 474,91 рублей (пятнадцать тысяч четыреста семьдесят четыре рубля 91 копейка). score: 0.9935365836566061
# True
#  Размер обеспечения гарантийных обязательств: 1% от начальной (максимальной) цены контракта (договора), что составляет 15 474,91 рублей (пятнадцать тысяч четыреста семьдесят четыре рубля 91 копейка).
# 461 из 500 предсказано
#  Размер обеспечения исполнения контракта: составляет 10% начальной (максимальной) цены контракта score: 0.9866206940081698
# True
#  Размер обеспечения исполнения контракта: составляет 10% начальной (максимальной) цены контракта
# 462 из 500 предсказано
#  Размер обеспечения исполнения договора: 5% НМЦД – 63 478 (Шестьдесят три тысячи четыреста семьдесят восемь) рублей 36 копеек. score: 0.9864399702926797
# False
#  Размер обеспечения исполнения договора: 5% НМЦД
# 463 из 500 предсказано
#  Обеспечение гарантийных обязательств установлено в размере 1% от начальной (максимальной) цены контракта и составляет 5 316,20 (Пять тысяч триста шестнадцать руб. 20 коп.). score: 0.9935374940613919
# False
#  Обеспечение гарантийных обязательств установлено в размере 1% от начальной (максимальной) цены контракта и составляет 5 316,20
# 464 из 500 предсказано
#  Сумма обеспечения исполнения договора предусмотрена в следующем размере: 5 (Пяти) % от начальной (максимальной) цены договора score: 0.9868914124837431
# True
#  Сумма обеспечения исполнения договора предусмотрена в следующем размере: 5 (Пяти) % от начальной (максимальной) цены договора
# 465 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 2 362,70, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9854070915601845
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 466 из 500 предсказано
#  Размер обеспечения исполнения Контракта составляет _____ рублей ___ копеек (5% процентов от начальной (максимальной) цены контракта score: 0.9868729382021769
# False
#  Размер обеспечения исполнения Контракта составляет _____ рублей ___ копеек (5% процентов от начальной (максимальной) цены контракта).
# 467 из 500 предсказано
#  Обеспечение исполнения настоящего Контракта установлено в размере 1 453,16, эквивалентном 0,50 % от начальной (максимальной) цены контракта.[footnoteRef:16]. [16: score: 0.9839346463510902
# False
#  Размер обеспечение исполнения контракта устанавливается от 0,5 % до 30 % начальной (максимальной) цены контракта
# 468 из 500 предсказано
#  9.8. - адреса домов на территории муниципального района score: 0.005078084054563099
# False
#  Обеспечение исполнения настоящего Контракта устанавливается в размере 1 (одного) процентов от цены Контракта и составляет____ (__) руб. __ коп.
# 469 из 500 предсказано
#  Размер и валюта обеспечения договора: 5% от начальной (максимальной) цены договора: 541 684,50 рублей НДС не облагается score: 0.9934397513809392
# False
#  Размер обеспечения исполнения обязательств на период действия гарантийных обязательств Размер и валюта обеспечения: 2% от начальной (максимальной) цены договора: 216 673,80 рублей
# 470 из 500 предсказано
#  Размер обеспечения исполнения контракта 5.00% score: 0.9863327435514745
# True
#  Размер обеспечения исполнения контракта 5.00%
# 471 из 500 предсказано
#  None score: None
# True
#  None
# 472 из 500 предсказано
#  Размер обеспечения исполнения договора составляет 5% (пять процентов) начальной максимальной цены договора, что составляет 7153,85 рублей Договор заключается только после предоставления участником аукциона score: 0.9867063298189895
# False
#  Размер обеспечения исполнения договора составляет 5% (пять процентов) начальной максимальной цены договора
# 473 из 500 предсказано
#  Если при проведении закупки обеспечение исполнения договора не было установлено, а участником, с которым заключается договор предложена цена договора, которая на двадцать пять и более процентов ниже начальной (максимальной) цены договора, договор заключается только после предоставления таким участником обеспечения исполнения договора в размере 25% начальной (максимальной) цены договора score: 0.007823191603407916
# False
#  договор заключается только после предоставления таким участником обеспечения исполнения договора в размере 25% начальной (максимальной) цены договора
# 474 из 500 предсказано
#  Поставщик обязан предоставить обеспечение исполнения договора в размере 5% от начальной (максимальной) цены договора: 100 000,00 (Сто тысяч рублей 00 копеек). score: 0.9863455265085616
# True
#  Поставщик обязан предоставить обеспечение исполнения договора в размере 5% от начальной (максимальной) цены договора: 100 000,00 (Сто тысяч рублей 00 копеек).
# 475 из 500 предсказано
#  Если при проведении закупки обеспечение исполнения договора не было установлено, а участником, с которым заключается договор предложена цена договора, которая на двадцать пять и более процентов ниже начальной (максимальной) цены договора, договор заключается только после предоставления таким участником обеспечения исполнения договора в размере 25% начальной (максимальной) цены договора score: 0.007823191603407916
# False
#  договор заключается только после предоставления таким участником обеспечения исполнения договора в размере 25% начальной (максимальной) цены договора
# 476 из 500 предсказано
#  None score: None
# True
#  None
# 477 из 500 предсказано
#  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от начальной (максимальной) цены Контракта score: 0.9867594801822948
# True
#  Поставщик при заключении Контракта должен предоставить Заказчику обеспечение исполнения Контракта в размере 5 % от начальной (максимальной) цены Контракта
# 478 из 500 предсказано
#  None score: None
# True
#  None
# 479 из 500 предсказано
#  Размер обеспечения исполнения контракта 1383.33 Российский рубль score: 0.9866002721429172
# True
#  Размер обеспечения исполнения контракта 1383.33 Российский рубль
# 480 из 500 предсказано
#  Подрядчиком обеспечения гарантийных обязательств в размере 5 % от начальной (максимальной) цены Договора, что составляет что составляет 584 558 (Пятьсот восемьдесят четыре тысячи пятьсот пятьдесят восемь) рублей 65 коп. score: 0.9935693218784906
# False
#  Предоставление Подрядчиком обеспечения гарантийных обязательств в размере 5 % от начальной (максимальной) цены Договора, что составляет что составляет 584 558
# 481 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 20000.00 Российский рубль score: 0.993460986884322
# True
#  Размер обеспечения гарантийных обязательств 20000.00 Российский рубль
# 482 из 500 предсказано
#  11. ФОРМУ СОГЛАСОВАЛИ: score: 0.004105260507575565
# False
#  None
# 483 из 500 предсказано
#  Размер обеспечения исполнения договора может составлять 5 процентов от начальной (максимальной) цены договора. score: 0.9865013169241932
# True
#  Размер обеспечения исполнения договора может составлять 5 процентов от начальной (максимальной) цены договора.
# 484 из 500 предсказано
#  Обеспечение исполнения Контракта устанавливается в размере 5 % от цены, по которой заключается Контракт score: 0.9868019364711317
# False
#  Обеспечение исполнения Контракта устанавливается в размере 5 % от цены, по которой заключается Контракт, что составляет __
# 485 из 500 предсказано
#  Установить обеспечение гарантийных обязательств (Не более 10 %) score: 0.9859138669981133
# False
#  Установить обеспечения исполнения контракта (от 0,5% до 30%) % обеспечения
# 486 из 500 предсказано
#  Сумма обеспечения контракта составляет 10 % от цены контракта score: 0.9866484873493931
# True
#  Сумма обеспечения контракта составляет 10 % от цены контракта
# 487 из 500 предсказано
#  Размер обеспечения исполнения контракта составляет 5 % от начальной (максимальной) цены контракта. score: 0.9934605477741574
# False
#  Размер обеспечения исполнения гарантийных обязательств составляет 0,01 % от начальной (максимальной) цены контракта и предоставляется до момента оформления документа
# 488 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 175630.00 Российский рубль score: 0.9934459119576147
# True
#  Размер обеспечения гарантийных обязательств 175630.00 Российский рубль
# 489 из 500 предсказано
#  Сумма обеспечения настоящего Договора составляет: 240 000,00 рублей. score: 0.9848047735789572
# True
#  Сумма обеспечения настоящего Договора составляет: 240 000,00 рублей.
# 490 из 500 предсказано
#  Размер обеспечения исполнения договора: 5 % от начальной (максимальной) цены договора score: 0.9867287529885798
# True
#  Размер обеспечения исполнения договора: 5 % от начальной (максимальной) цены договора
# 491 из 500 предсказано
#  Подрядчику надлежит предоставить обеспечение гарантийных обязательств в течение 5 дней и в размере 342 858,25 рублей, до оформления приемки выполненных работ по Контракту. score: 0.993446839541129
# False
#  по контракту Подрядчику надлежит предоставить обеспечение гарантийных обязательств в течение 5 дней и в размере 342 858,25 рублей, до оформления приемки выполненных работ по Контракту.
# 492 из 500 предсказано
#  None score: None
# True
#  None
# 493 из 500 предсказано
#  Размер обеспечения исполнения контракта 5.00% score: 0.9863327435514745
# True
#  Размер обеспечения исполнения контракта 5.00%
# 494 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 80905.35 Российский рубль score: 0.9934790494686172
# True
#  Размер обеспечения гарантийных обязательств 80905.35 Российский рубль
# 495 из 500 предсказано
#  Размер обеспечения исполнения контракта 10.00% score: 0.9863875463063003
# True
#  Размер обеспечения исполнения контракта 10.00%
# 496 из 500 предсказано
#  Размер обеспечения исполнения контракта: 10% от начальной (максимальной) цены Контракта. score: 0.986596277490946
# True
#  Размер обеспечения исполнения контракта: 10% от начальной (максимальной) цены Контракта.
# 497 из 500 предсказано
#  Размер обеспечения гарантийных обязательств 1350122.66 Российский рубль score: 0.9934774660671221
# True
#  Размер обеспечения гарантийных обязательств 1350122.66 Российский рубль
# 498 из 500 предсказано
#  Обеспечение исполнения Договора: 5% от начальной (максимальной) цены Договора, что составляет: score: 0.9867958419117414
# False
#  Обеспечение исполнения Договора: 5% от начальной (максимальной) цены Договора
# 499 из 500 предсказано
#  Размер обеспечения исполнения Контракта составляет__________ (__________) рублей _______ копеек (10 процентов начальной (максимальной) цены Контракта). score: 0.9859319051902602
# True
#  Размер обеспечения исполнения Контракта составляет__________ (__________) рублей _______ копеек (10 процентов начальной (максимальной) цены Контракта).

# %%
text_accuracy_score(pred, df_500.loc[:, 'target'].values)
# Out:
# 0.55

# %% [markdown]
# accurcy 0.55 для сравнения предскажем тоже самое с помощью xgboost. на том же самом датасете xgboost показывает accuracy 0.62
